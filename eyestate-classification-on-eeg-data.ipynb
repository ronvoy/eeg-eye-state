# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install tensorflow numpy scipy pandas scikit-learn matplotlib seaborn PyWavelets scikeras

import tensorflow.compat.v1 as tf
from sklearn.metrics import confusion_matrix
import numpy as np
from scipy.io import loadmat
import os
from pywt import wavedec
from functools import reduce
from scipy import signal
from scipy.stats import entropy
from scipy.fft import fft, ifft
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from tensorflow import keras as K
import matplotlib.pyplot as plt
import scipy
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold,cross_validate
from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential, Model, load_model
import matplotlib.pyplot as plt;
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.decomposition import PCA
from tensorflow import keras
from sklearn.model_selection import cross_val_score
from tensorflow.keras.layers import Conv1D,Conv2D,Add
from tensorflow.keras.layers import MaxPool1D, MaxPooling2D
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: tensorflow in /Users/rohan-m1/venv/lib/python3.10/site-packages (2.19.0)
# Requirement already satisfied: numpy in /Users/rohan-m1/venv/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scipy in /Users/rohan-m1/venv/lib/python3.10/site-packages (1.15.3)
# Requirement already satisfied: pandas in /Users/rohan-m1/venv/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: scikit-learn in /Users/rohan-m1/venv/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: matplotlib in /Users/rohan-m1/venv/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: seaborn in /Users/rohan-m1/venv/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: PyWavelets in /Users/rohan-m1/venv/lib/python3.10/site-packages (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/rohan-m1/venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /Users/rohan-m1/venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/rohan-m1/venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/rohan-m1/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 26
#      24 from sklearn.model_selection import KFold,cross_validate
#      25 from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape
# ---> 26 from keras.wrappers.scikit_learn import KerasClassifier
#      27 from sklearn.metrics import classification_report
#      28 from tensorflow.keras.models import Sequential, Model, load_model
#
# ModuleNotFoundError: No module named 'keras.wrappers.scikit_learn'

# %%
df = pd.read_csv("eeg_eye_state.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14980 entries, 0 to 14979
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AF3           14980 non-null  float64
#  1   F7            14980 non-null  float64
#  2   F3            14980 non-null  float64
#  3   FC5           14980 non-null  float64
#  4   T7            14980 non-null  float64
#  5   P7            14980 non-null  float64
#  6   O1            14980 non-null  float64
#  7   O2            14980 non-null  float64
#  8   P8            14980 non-null  float64
#  9   T8            14980 non-null  float64
#  10  FC6           14980 non-null  float64
#  11  F4            14980 non-null  float64
#  12  F8            14980 non-null  float64
#  13  AF4           14980 non-null  float64
#  14  eyeDetection  14980 non-null  int64
# dtypes: float64(14), int64(1)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#                  AF3            F7            F3            FC5            T7  \
# count   14980.000000  14980.000000  14980.000000   14980.000000  14980.000000
# mean     4321.917777   4009.767694   4264.022433    4164.946326   4341.741075
# std      2492.072174     45.941672     44.428052    5216.404632     34.738821
# min      1030.770000   2830.770000   1040.000000    2453.330000   2089.740000
# 25%      4280.510000   3990.770000   4250.260000    4108.210000   4331.790000
# 50%      4294.360000   4005.640000   4262.560000    4120.510000   4338.970000
# 75%      4311.790000   4023.080000   4270.770000    4132.310000   4347.180000
# max    309231.000000   7804.620000   6880.510000  642564.000000   6474.360000
#
#                   P7             O1            O2             P8  \
# count   14980.000000   14980.000000  14980.000000   14980.000000
# mean     4644.022379    4110.400160   4616.056904    4218.826610
# std      2924.789537    4600.926543     29.292603    2136.408523
# min      2768.210000    2086.150000   4567.180000    1357.950000
# 25%      4611.790000    4057.950000   4604.620000    4190.770000
# 50%      4617.950000    4070.260000   4613.330000    4199.490000
# 75%      4626.670000    4083.590000   4624.100000    4209.230000
# max    362564.000000  567179.000000   7264.100000  265641.000000
#
#                  T8           FC6            F4             F8            AF4  \
# count  14980.000000  14980.000000  14980.000000   14980.000000   14980.000000
# mean    4231.316200   4202.456900   4279.232774    4615.205336    4416.435832
# std       38.050903     37.785981     41.544312    1208.369958    5891.285043
# min     1816.410000   3273.330000   2257.950000      86.666700    1366.150000
# 25%     4220.510000   4190.260000   4267.690000    4590.770000    4342.050000
# 50%     4229.230000   4200.510000   4276.920000    4603.080000    4354.870000
# 75%     4239.490000   4211.280000   4287.180000    4617.440000    4372.820000
# max     6674.360000   6823.080000   7002.560000  152308.000000  715897.000000
#
#        eyeDetection
# count  14980.000000
# mean       0.448798
# std        0.497388
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.isnull().sum()
# Out:
# AF3             0
# F7              0
# F3              0
# FC5             0
# T7              0
# P7              0
# O1              0
# O2              0
# P8              0
# T8              0
# FC6             0
# F4              0
# F8              0
# AF4             0
# eyeDetection    0
# dtype: int64

# %%
plt.figure(figsize = (15,15))
cor_matrix = df.corr()
sns.heatmap(cor_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %%
# Plotting target distribution 
plt.figure(figsize=(6,6))
df['eyeDetection'].value_counts().plot.pie(explode=[0.1,0.1], autopct='%1.1f%%', shadow=True, textprops={'fontsize':16}).set_title("Target distribution")
# Out:
# Text(0.5, 1.0, 'Target distribution')

# %%
data = df.copy()
y= data.pop('eyeDetection')
x= data

# %%
x_new = StandardScaler().fit_transform(x)

# %%
x_new = pd.DataFrame(x_new) 
x_new.columns = x.columns

# %% [markdown]
# ## Dividing into Training and Validation sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x_new,y,test_size=0.15)

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12733, 14), (2247, 14), (12733,), (2247,))

# %% [markdown]
# ## Reshaping the data as required by the model

# %%
x_train = np.array(x_train).reshape(-1,14,1)
x_test = np.array(x_test).reshape(-1,14,1)

# %%
x_train.shape, x_test.shape,y_train.shape,y_test.shape
# Out:
# ((12733, 14, 1), (2247, 14, 1), (12733,), (2247,))

# %% [markdown]
# ## Defining the Model's architecture

# %%
inputs = tf.keras.Input(shape=(14,1))

Dense1 = Dense(64, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(inputs)

#Dense2 = Dense(128, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(Dense1)
#Dense3 = Dense(256, activation = 'relu',kernel_regularizer=keras.regularizers.l2())(Dense2)

lstm_1=  Bidirectional(LSTM(256, return_sequences = True))(Dense1)
drop = Dropout(0.3)(lstm_1)
lstm_3=  Bidirectional(LSTM(128, return_sequences = True))(drop)
drop2 = Dropout(0.3)(lstm_3)

flat = Flatten()(drop2)

#Dense_1 = Dense(256, activation = 'relu')(flat)

Dense_2 = Dense(128, activation = 'relu')(flat)
outputs = Dense(1, activation='sigmoid')(Dense_2)

model = tf.keras.Model(inputs, outputs)

model.summary()
# Out:
# 2022-06-30 05:48:27.479009: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 14, 1)]           0
# _________________________________________________________________
# dense (Dense)                (None, 14, 64)            128
# _________________________________________________________________
# bidirectional (Bidirectional (None, 14, 512)           657408
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 512)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 14, 256)           656384
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 256)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 3584)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               458880
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,772,929
# Trainable params: 1,772,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# The loss function used will be 'Binary CrossEntropy'. We will be using callback functions like Early_Stopping to avoid overfitting and lr_scheduler to change the learning rate while model trains.

# %%
def train_model(model,x_train, y_train,x_test,y_test, save_to, epoch = 2):

        opt_adam = keras.optimizers.Adam(learning_rate=0.001)

        es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
        mc = ModelCheckpoint(save_to + '_best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
        lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 0.001 * np.exp(-epoch / 10.))
        
        model.compile(optimizer=opt_adam,
                  loss=['binary_crossentropy'],
                  metrics=['accuracy'])
        
        history = model.fit(x_train,y_train,
                        batch_size=20,
                        epochs=epoch,
                        validation_data=(x_test,y_test),
                        callbacks=[es,mc,lr_schedule])
        
        saved_model = load_model(save_to + '_best_model.h5')
        
        return model,history

# %% [markdown]
# ## Analyzing the results.

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred =model.predict(x_test)
y_pred = np.array(y_pred >= 0.5, dtype = np.int)
confusion_matrix(y_test, y_pred)
# Out:
# 2022-06-30 05:48:30.234365: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# array([[ 177, 1069],
#        [ 206,  795]])

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.14      0.22      1246
#            1       0.43      0.79      0.55      1001
#
#     accuracy                           0.43      2247
#    macro avg       0.44      0.47      0.39      2247
# weighted avg       0.45      0.43      0.37      2247

# %%
model,history = train_model(model, x_train, y_train,x_test, y_test, save_to= './', epoch = 100)
# Out:
# Epoch 1/100
# 637/637 [==============================] - 76s 107ms/step - loss: 0.6771 - accuracy: 0.5772 - val_loss: 0.6766 - val_accuracy: 0.5906
#
# Epoch 00001: val_accuracy improved from -inf to 0.59057, saving model to ./_best_model.h5
# Epoch 2/100
# 637/637 [==============================] - 66s 104ms/step - loss: 0.6475 - accuracy: 0.6035 - val_loss: 0.6316 - val_accuracy: 0.6208
#
# Epoch 00002: val_accuracy improved from 0.59057 to 0.62083, saving model to ./_best_model.h5
# Epoch 3/100
# 637/637 [==============================] - 65s 102ms/step - loss: 0.6079 - accuracy: 0.6557 - val_loss: 0.5712 - val_accuracy: 0.6938
#
# Epoch 00003: val_accuracy improved from 0.62083 to 0.69381, saving model to ./_best_model.h5
# Epoch 4/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.5573 - accuracy: 0.7093 - val_loss: 0.5375 - val_accuracy: 0.7308
#
# Epoch 00004: val_accuracy improved from 0.69381 to 0.73075, saving model to ./_best_model.h5
# Epoch 5/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.5064 - accuracy: 0.7460 - val_loss: 0.4759 - val_accuracy: 0.7575
#
# Epoch 00005: val_accuracy improved from 0.73075 to 0.75745, saving model to ./_best_model.h5
# Epoch 6/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.4708 - accuracy: 0.7706 - val_loss: 0.4507 - val_accuracy: 0.7775
#
# Epoch 00006: val_accuracy improved from 0.75745 to 0.77748, saving model to ./_best_model.h5
# Epoch 7/100
# 637/637 [==============================] - 68s 106ms/step - loss: 0.4467 - accuracy: 0.7872 - val_loss: 0.4323 - val_accuracy: 0.7971
#
# Epoch 00007: val_accuracy improved from 0.77748 to 0.79706, saving model to ./_best_model.h5
# Epoch 8/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.4222 - accuracy: 0.8015 - val_loss: 0.4081 - val_accuracy: 0.8100
#
# Epoch 00008: val_accuracy improved from 0.79706 to 0.80997, saving model to ./_best_model.h5
# Epoch 9/100
# 637/637 [==============================] - 66s 104ms/step - loss: 0.4000 - accuracy: 0.8126 - val_loss: 0.4076 - val_accuracy: 0.8015
#
# Epoch 00009: val_accuracy did not improve from 0.80997
# Epoch 10/100
# 637/637 [==============================] - 66s 104ms/step - loss: 0.3873 - accuracy: 0.8227 - val_loss: 0.3976 - val_accuracy: 0.8166
#
# Epoch 00010: val_accuracy improved from 0.80997 to 0.81664, saving model to ./_best_model.h5
# Epoch 11/100
# 637/637 [==============================] - 71s 112ms/step - loss: 0.3699 - accuracy: 0.8286 - val_loss: 0.3857 - val_accuracy: 0.8135
#
# Epoch 00011: val_accuracy did not improve from 0.81664
# Epoch 12/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.3536 - accuracy: 0.8382 - val_loss: 0.3781 - val_accuracy: 0.8215
#
# Epoch 00012: val_accuracy improved from 0.81664 to 0.82154, saving model to ./_best_model.h5
# Epoch 13/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.3436 - accuracy: 0.8432 - val_loss: 0.3651 - val_accuracy: 0.8300
#
# Epoch 00013: val_accuracy improved from 0.82154 to 0.83000, saving model to ./_best_model.h5
# Epoch 14/100
# 637/637 [==============================] - 67s 106ms/step - loss: 0.3307 - accuracy: 0.8525 - val_loss: 0.3545 - val_accuracy: 0.8407
#
# Epoch 00014: val_accuracy improved from 0.83000 to 0.84068, saving model to ./_best_model.h5
# Epoch 15/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.3225 - accuracy: 0.8565 - val_loss: 0.3556 - val_accuracy: 0.8367
#
# Epoch 00015: val_accuracy did not improve from 0.84068
# Epoch 16/100
# 637/637 [==============================] - 68s 106ms/step - loss: 0.3126 - accuracy: 0.8619 - val_loss: 0.3495 - val_accuracy: 0.8385
#
# Epoch 00016: val_accuracy did not improve from 0.84068
# Epoch 17/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.3078 - accuracy: 0.8626 - val_loss: 0.3409 - val_accuracy: 0.8482
#
# Epoch 00017: val_accuracy improved from 0.84068 to 0.84824, saving model to ./_best_model.h5
# Epoch 18/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2950 - accuracy: 0.8697 - val_loss: 0.3370 - val_accuracy: 0.8496
#
# Epoch 00018: val_accuracy improved from 0.84824 to 0.84958, saving model to ./_best_model.h5
# Epoch 19/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2884 - accuracy: 0.8730 - val_loss: 0.3380 - val_accuracy: 0.8469
#
# Epoch 00019: val_accuracy did not improve from 0.84958
# Epoch 20/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2816 - accuracy: 0.8768 - val_loss: 0.3427 - val_accuracy: 0.8509
#
# Epoch 00020: val_accuracy improved from 0.84958 to 0.85091, saving model to ./_best_model.h5
# Epoch 21/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2779 - accuracy: 0.8776 - val_loss: 0.3311 - val_accuracy: 0.8527
#
# Epoch 00021: val_accuracy improved from 0.85091 to 0.85269, saving model to ./_best_model.h5
# Epoch 22/100
# 637/637 [==============================] - 66s 104ms/step - loss: 0.2731 - accuracy: 0.8820 - val_loss: 0.3326 - val_accuracy: 0.8563
#
# Epoch 00022: val_accuracy improved from 0.85269 to 0.85625, saving model to ./_best_model.h5
# Epoch 23/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2715 - accuracy: 0.8830 - val_loss: 0.3313 - val_accuracy: 0.8509
#
# Epoch 00023: val_accuracy did not improve from 0.85625
# Epoch 24/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2618 - accuracy: 0.8877 - val_loss: 0.3291 - val_accuracy: 0.8540
#
# Epoch 00024: val_accuracy did not improve from 0.85625
# Epoch 25/100
# 637/637 [==============================] - 67s 106ms/step - loss: 0.2582 - accuracy: 0.8886 - val_loss: 0.3269 - val_accuracy: 0.8554
#
# Epoch 00025: val_accuracy did not improve from 0.85625
# Epoch 26/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2537 - accuracy: 0.8908 - val_loss: 0.3341 - val_accuracy: 0.8620
#
# Epoch 00026: val_accuracy improved from 0.85625 to 0.86204, saving model to ./_best_model.h5
# Epoch 27/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2514 - accuracy: 0.8910 - val_loss: 0.3306 - val_accuracy: 0.8598
#
# Epoch 00027: val_accuracy did not improve from 0.86204
# Epoch 28/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2494 - accuracy: 0.8934 - val_loss: 0.3268 - val_accuracy: 0.8571
#
# Epoch 00028: val_accuracy did not improve from 0.86204
# Epoch 29/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2437 - accuracy: 0.8934 - val_loss: 0.3296 - val_accuracy: 0.8589
#
# Epoch 00029: val_accuracy did not improve from 0.86204
# Epoch 30/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2392 - accuracy: 0.8984 - val_loss: 0.3267 - val_accuracy: 0.8563
#
# Epoch 00030: val_accuracy did not improve from 0.86204
# Epoch 31/100
# 637/637 [==============================] - 65s 102ms/step - loss: 0.2389 - accuracy: 0.8996 - val_loss: 0.3285 - val_accuracy: 0.8589
#
# Epoch 00031: val_accuracy did not improve from 0.86204
# Epoch 32/100
# 637/637 [==============================] - 65s 102ms/step - loss: 0.2368 - accuracy: 0.9005 - val_loss: 0.3271 - val_accuracy: 0.8594
#
# Epoch 00032: val_accuracy did not improve from 0.86204
# Epoch 33/100
# 637/637 [==============================] - 67s 104ms/step - loss: 0.2337 - accuracy: 0.8994 - val_loss: 0.3274 - val_accuracy: 0.8603
#
# Epoch 00033: val_accuracy did not improve from 0.86204
# Epoch 34/100
# 637/637 [==============================] - 66s 103ms/step - loss: 0.2331 - accuracy: 0.9003 - val_loss: 0.3257 - val_accuracy: 0.8567
#
# Epoch 00034: val_accuracy did not improve from 0.86204
# Epoch 35/100
# 637/637 [==============================] - 66s 104ms/step - loss: 0.2307 - accuracy: 0.9000 - val_loss: 0.3281 - val_accuracy: 0.8598
#
# Epoch 00035: val_accuracy did not improve from 0.86204
# Epoch 36/100
# 637/637 [==============================] - 67s 106ms/step - loss: 0.2247 - accuracy: 0.9039 - val_loss: 0.3284 - val_accuracy: 0.8594
#
# Epoch 00036: val_accuracy did not improve from 0.86204
# Epoch 37/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2249 - accuracy: 0.9047 - val_loss: 0.3263 - val_accuracy: 0.8603
#
# Epoch 00037: val_accuracy did not improve from 0.86204
# Epoch 38/100
# 637/637 [==============================] - 69s 109ms/step - loss: 0.2262 - accuracy: 0.9040 - val_loss: 0.3276 - val_accuracy: 0.8589
#
# Epoch 00038: val_accuracy did not improve from 0.86204
# Epoch 39/100
# 637/637 [==============================] - 69s 108ms/step - loss: 0.2250 - accuracy: 0.9041 - val_loss: 0.3280 - val_accuracy: 0.8611
#
# Epoch 00039: val_accuracy did not improve from 0.86204
# Epoch 40/100
# 637/637 [==============================] - 70s 109ms/step - loss: 0.2205 - accuracy: 0.9043 - val_loss: 0.3299 - val_accuracy: 0.8629
#
# Epoch 00040: val_accuracy improved from 0.86204 to 0.86293, saving model to ./_best_model.h5
# Epoch 41/100
# 637/637 [==============================] - 68s 106ms/step - loss: 0.2208 - accuracy: 0.9075 - val_loss: 0.3282 - val_accuracy: 0.8616
#
# Epoch 00041: val_accuracy did not improve from 0.86293
# Epoch 42/100
# 637/637 [==============================] - 67s 105ms/step - loss: 0.2220 - accuracy: 0.9035 - val_loss: 0.3310 - val_accuracy: 0.8607
#
# Epoch 00042: val_accuracy did not improve from 0.86293
# Epoch 43/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2186 - accuracy: 0.9078 - val_loss: 0.3289 - val_accuracy: 0.8625
#
# Epoch 00043: val_accuracy did not improve from 0.86293
# Epoch 44/100
# 637/637 [==============================] - 68s 107ms/step - loss: 0.2175 - accuracy: 0.9087 - val_loss: 0.3298 - val_accuracy: 0.8616
#
# Epoch 00044: val_accuracy did not improve from 0.86293
# Epoch 00044: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Analyzing the results

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred =model.predict(x_test)
y_pred = np.array(y_pred >= 0.5, dtype = np.int)
confusion_matrix(y_test, y_pred)
# Out:
# array([[1105,  141],
#        [ 170,  831]])

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      1246
#            1       0.85      0.83      0.84      1001
#
#     accuracy                           0.86      2247
#    macro avg       0.86      0.86      0.86      2247
# weighted avg       0.86      0.86      0.86      2247
